# %% [markdown]
# <a href="https://colab.research.google.com/github/SlepenkovaDaria/My-homework/blob/main/SecondDZ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem 1

# %% [markdown]
# Let $f(x) = 2\sin x - \cos{2x}$. Write a function `beauty_derivative_plot` that takes a point $x$ and plots the function $f(x)$ and its derivative $f'(x)$ in the range $x \in [-2\pi, 2\pi]$. The function should also plot the tangent line to the function at the point $x$.
#
# Example of output for $x = -3, -2, 1.7$:
#
# ```python
# beauty_derivative_plot(-3)
# ```
# <img src="https://i.ibb.co/zTdYLC0J/tangent-line-3-0.png" width="600"/>
#
# ```python
# beauty_derivative_plot(-2)
# ```
# <img src="https://i.ibb.co/hFXNZ7wS/tangent-line-2-0.png" width="600"/>
#
# ```python
# beauty_derivative_plot(1.7)
# ```
# <img src="https://i.ibb.co/217yHstn/tangent-line-1-7.png" width="600"/>

# %%
import matplotlib.pyplot as plt
import numpy as np

def beauty_derivative_plot(my_x):
    plt.figure(figsize = (12, 6))
    x = np.linspace(-2 * np.pi, 2 * np.pi, 100)
    f1 = lambda x : 2 * np.sin(x) - np.cos(2 * x)
    f2 = lambda x: 2 * np.cos(x) + 2 * np.sin(2 * x)
    my_y = f1(my_x)
    my_y_div = f2(my_x)
    x_line = np.linspace(my_x - 1, my_x + 1, 100)
    y_line = my_y +my_y_div * (x_line - my_x)

    plt.grid(True)
    plt.xlim(-2 * np.pi, 2 * np.pi)
    plt.ylim(-4, 4)
    plt.plot(x, f1(x), "b-", label = "f(x) = 2sin(x) - cos(2x)")
    plt.plot(x, f2(x), "r--", label = "f'(x) = 2cos(x) + 2sin(2x)")
    plt.plot(x_line, y_line, "g-", label = f"Tangent at x = {my_x}")
    plt.plot(my_x, my_y, "ko")
    plt.plot([my_x, my_x], [my_y, 0], "m--")
    plt.plot([my_x, 0], [my_y, my_y], "m--")
    plt.annotate(f"f'({my_x}) = {round(f2(my_x), 2)}", xy=(my_x, my_y), xytext=(my_x - 0.5, my_y - 2),
                fontweight = "bold", arrowprops = dict(arrowstyle = "-|>", color = "black", lw = 1,
                connectionstyle = "arc3, rad = 0.2"))
    plt.legend(loc = "upper right")
    plt.title("Function, Derivative, and Tangent Line")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.show()

point = np.double(input())
if point <= 2 * np.pi and point >= -2 * np.pi:
    beauty_derivative_plot(point)
else:
    print("Choose another point!")
# Out:
# -3

# %% [markdown]
# # Problem 2

# %% [markdown]
# The data in [populations.txt](http://www.scipy-lectures.org/_downloads/populations.txt) describes the populations of hares, lynxes and carrots in northern Canada during 20 years. Get the data with
# ```python
# np.loadtxt('http://www.scipy-lectures.org/_downloads/populations.txt')
# ```
# and do the following exercises **without for-loops (!!!)**.

# %% [markdown]
# Plot the population size of each species for each year on a single graph. Add
# legend and axis labels to the plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
import gdown

gdown.download("https://drive.google.com/uc?id=15WG5kwiq72NdaFpTlmWv0BTpM3ywwJGD", "populations.txt", quiet = False)

data = np.loadtxt("populations.txt")

year = data[:, 0]
hares = data[:, 1]
lynxes = data[:, 2]
carrots = data[:, 3]

plt.figure(figsize = (12, 6))
plt.plot(year, hares, "b-", label = "Hares")
plt.plot(year, lynxes, "g-", label = "Lynxes")
plt.plot(year, carrots, "r-", label = "Carrots")

plt.xticks(year)
plt.xlim(1900, 1920)
plt.grid(True)
plt.xlabel("Years")
plt.ylabel("Population")
plt.title("Population of hares, lynxes and carrots in Northern Canada")
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15WG5kwiq72NdaFpTlmWv0BTpM3ywwJGD
# To: /content/populations.txt
# 100%|██████████| 532/532 [00:00<00:00, 2.02MB/s]

# %% [markdown]
# Find which year each species had the largest population. Mark these years in the plot of populations.

# %%
import numpy as np
import matplotlib.pyplot as plt
import gdown

gdown.download("https://drive.google.com/uc?id=15WG5kwiq72NdaFpTlmWv0BTpM3ywwJGD", "populations.txt", quiet = False)

data = np.loadtxt("populations.txt")

year = data[:, 0]
hares = data[:, 1]
lynxes = data[:, 2]
carrots = data[:, 3]

max_hares_index = np.argmax(hares)
max_lynxes_index = np.argmax(lynxes)
max_carrots_index = np.argmax(carrots)

max_hares_year = year[max_hares_index]
max_lynxes_year = year[max_lynxes_index]
max_carrots_year = year[max_carrots_index]

max_hares = hares[max_hares_index]
max_lynxes = lynxes[max_lynxes_index]
max_carrots = carrots[max_carrots_index]

plt.figure(figsize=(12, 6))
plt.plot(year, hares, "b-", label = "Hares")
plt.plot(year, lynxes, "g-", label = "Lynxes")
plt.plot(year, carrots, "r-", label = "Carrots")
plt.plot(max_hares_year, max_hares, "bo", markersize = 10,
         label = f"Hares max: {max_hares}, year: {int(max_hares_year)}")
plt.plot(max_lynxes_year, max_lynxes, "go", markersize = 10,
         label = f"Lynxes max: {max_lynxes}, year: {int(max_lynxes_year)}")
plt.plot(max_carrots_year, max_carrots, "ro", markersize = 10,
         label = f"Carrots max: {max_carrots}, year: {int(max_carrots_year)}")
plt.plot([max_hares_year, max_hares_year, ], [max_hares, 0], "b--")
plt.plot([max_lynxes_year, max_lynxes_year], [max_lynxes, 0], "g--")
plt.plot([max_carrots_year, max_carrots_year], [max_carrots, 0], "r--")

plt.xticks(year)
plt.ylim(0, )
plt.grid(True)
plt.xlabel("Years")
plt.ylabel("Population")
plt.title("Population of hares, lynxes and carrots in Northern Canada")
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15WG5kwiq72NdaFpTlmWv0BTpM3ywwJGD
# To: /content/populations.txt
# 100%|██████████| 532/532 [00:00<00:00, 1.87MB/s]

# %% [markdown]
# Assuming total population of hares and lynxes is 100%, plot stacked bar graph showing ratio of each specis for each year in the period.

# %%
import numpy as np
import matplotlib.pyplot as plt
import gdown

gdown.download("https://drive.google.com/uc?id=15WG5kwiq72NdaFpTlmWv0BTpM3ywwJGD", "populations.txt", quiet = False)

data = np.loadtxt("populations.txt")
year = data[:, 0].astype(int)
hares = data[:, 1]
lynxes = data[:, 2]
hares_percent = (hares / (hares + lynxes)) * 100
lynxes_percent = (lynxes / (hares + lynxes)) * 100

plt.figure(figsize=(16, 6))
x = np.arange(len(year))
plt.bar(x - 0.2, hares_percent, 0.4, label = "Hares", color = "blue", alpha = 0.6)
plt.bar(x + 0.2, lynxes_percent, 0.4, label = "Lynxes", color = "green", alpha = 0.6)

plt.xlabel("Year")
plt.ylabel("Percentage")
plt.title("Hares and Lynxes Percentage")
plt.xticks(x, year)
plt.yticks(range(0, 101, 10))
plt.legend()
plt.grid(True, axis = "y")

plt.show()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15WG5kwiq72NdaFpTlmWv0BTpM3ywwJGD
# To: /content/populations.txt
# 100%|██████████| 532/532 [00:00<00:00, 1.56MB/s]

# %% [markdown]
# Find the mean and std of the populations of each species. Plot the historgam of population for each species and show mean values with vertical line. Show each histogram in a separate plot. Arrange 3 plots in a row.

# %%
import numpy as np
import matplotlib.pyplot as plt
import gdown

gdown.download("https://drive.google.com/uc?id=15WG5kwiq72NdaFpTlmWv0BTpM3ywwJGD", "populations.txt", quiet = False)

data = np.loadtxt("populations.txt")

hares = data[:, 1]
lynxes = data[:, 2]
carrots = data[:, 3]

hares_mean = np.mean(hares)
lynxes_mean = np.mean(lynxes)
carrots_mean = np.mean(carrots)

hares_std = np.std(hares)
lynxes_std = np.std(lynxes)
carrots_std = np.std(carrots)

my_std = {"Hares": float(hares_std), "Lynxes": float(lynxes_std), "Carrots": float(carrots_std)}
my_mean = {"Hares": float(hares_mean), "Lynxes": float(lynxes_mean), "Carrots": float(carrots_mean)}

print(f"Std: {my_std}")
print(f"Mean: {my_mean}")

plt.figure(figsize = (14, 6))

plt.subplot(131)
plt.hist(hares, bins = "auto", edgecolor = "black", rwidth = 0.8)
plt.axvline(float(hares_mean), color = "red", linestyle = "--",
            linewidth = 2, label = f"Mean: {hares_mean:.0f}")
plt.text(50000, 7.3, f"Std: {hares_std:.0f}", fontsize = 15)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Hares")
plt.legend()
plt.grid(True, axis = "y")

plt.subplot(132)
plt.hist(lynxes, bins = "auto", edgecolor = "black", rwidth = 0.8)
plt.axvline(float(lynxes_mean), color = "red", linestyle = "--",
            linewidth = 2, label = f"Mean: {lynxes_mean:.0f}")
plt.text(35000, 10.7, f"Std: {lynxes_std:.0f}", fontsize = 15)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Lynxes")
plt.legend()
plt.grid(True, axis = "y")

plt.subplot(133)
plt.hist(carrots, bins = "auto", edgecolor = "black", rwidth = 0.8)
plt.axvline(float(carrots_mean), color = "red", linestyle = "--",
            linewidth = 2, label = f"Mean: {carrots_mean:.0f}")
plt.text(44000, 6.3, f"Std: {carrots_std:.0f}", fontsize = 15)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Carrots")
plt.legend()
plt.grid(True, axis = "y")
plt.show()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15WG5kwiq72NdaFpTlmWv0BTpM3ywwJGD
# To: /content/populations.txt
# 100%|██████████| 532/532 [00:00<00:00, 1.50MB/s]
# Std: {'Hares': 20897.906458089667, 'Lynxes': 16254.591536908763, 'Carrots': 3322.5062255844787}
# Mean: {'Hares': 34080.95238095238, 'Lynxes': 20166.666666666668, 'Carrots': 42400.0}

# %% [markdown]
# Find which species (hares or lynxes) has the largest population for each year. Print the result as [H, H, L, H, ...]. Plot a pie chart showing the ratio of "H" and "L" values.

# %%
import numpy as np
import matplotlib.pyplot as plt
import gdown

gdown.download("https://drive.google.com/uc?id=15WG5kwiq72NdaFpTlmWv0BTpM3ywwJGD", "populations.txt", quiet = False)

data = np.loadtxt("populations.txt")

hares = data[:, 1]
lynxes = data[:, 2]

comparison = np.where(hares > lynxes, "H", "L").tolist()
print("\n")
print(comparison)

hares_count = np.sum(hares > lynxes)
lynxes_count = np.sum(hares <= lynxes)

plt.figure(figsize = (8, 8))
plt.pie([hares_count, lynxes_count], labels = ["Hares", "Lynxes"], autopct = "%1.1f%%",
        textprops = {"fontsize": 16}, colors = ["yellowgreen", "dodgerblue"])
plt.title("The ratio of hares to lynxes", fontsize = 16)
plt.text(0, -1.3, f"{comparison}", horizontalalignment = "center", fontsize = 12)
plt.show()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15WG5kwiq72NdaFpTlmWv0BTpM3ywwJGD
# To: /content/populations.txt
# 100%|██████████| 532/532 [00:00<00:00, 1.78MB/s]
# ['H', 'H', 'H', 'H', 'L', 'L', 'L', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'L', 'L', 'L', 'H', 'H', 'H']

# %% [markdown]
# Plot the change in the hare population and in the lynx population for each year. Find the correlation coefficient between the both time series.

# %%
import numpy as np
import matplotlib.pyplot as plt
import gdown

gdown.download("https://drive.google.com/uc?id=15WG5kwiq72NdaFpTlmWv0BTpM3ywwJGD", "populations.txt", quiet = False)

data = np.loadtxt("populations.txt")

year = data[:, 0]
hares = data[:, 1]
lynxes = data[:, 2]

correlation = np.corrcoef(hares, lynxes)[0, 1]
print(f"Correlation coefficient: {correlation:.3f}")

plt.figure(figsize = (12, 6))
plt.plot(year, hares, "b-", label = "Hares")
plt.plot(year, lynxes, "g-", label = "Lynxes")

plt.xticks(year)
plt.xlim(1900, 1920)
plt.grid(True)
plt.xlabel("Years")
plt.ylabel("Population")
plt.title("Population of hares and lynxes in Northern Canada")
plt.text(1910, 75000, f"Correlation coefficient: {correlation:.3f}",
         horizontalalignment = "center", fontsize = 12)
plt.legend()
plt.show()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15WG5kwiq72NdaFpTlmWv0BTpM3ywwJGD
# To: /content/populations.txt
# 100%|██████████| 532/532 [00:00<00:00, 1.77MB/s]
# Correlation coefficient: 0.072

# %% [markdown]
# Using a scatter plot, show the population of hares vs lynxes by year (each point corresponds to a particular year, and the point coordinates correspond to the population of the two species in that year).

# %%
import numpy as np
import matplotlib.pyplot as plt
import gdown

gdown.download("https://drive.google.com/uc?id=15WG5kwiq72NdaFpTlmWv0BTpM3ywwJGD", "populations.txt", quiet = False)

data = np.loadtxt("populations.txt")

year = data[:, 0]
hares = data[:, 1]
lynxes = data[:, 2]

plt.figure(figsize = (8, 6))
plt.scatter(hares, lynxes, color = "purple", s = 150, alpha = 0.6)
plt.xlabel("Hares")
plt.ylabel("Lynxes")
plt.title("Hares and Lynxes Population")
plt.grid(True)
plt.show()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15WG5kwiq72NdaFpTlmWv0BTpM3ywwJGD
# To: /content/populations.txt
# 100%|██████████| 532/532 [00:00<00:00, 1.70MB/s]

# %% [markdown]
# Assume the population of hares in 1920 is unknown. Suggest a way to estimate this value. Compare an estimated value with the true value and print a ratio of the error to the true value.

# %%
import numpy as np
import gdown

gdown.download("https://drive.google.com/uc?id=15WG5kwiq72NdaFpTlmWv0BTpM3ywwJGD", "populations.txt", quiet = False)

data = np.loadtxt("populations.txt")

hares = data[:, 1]
true_value = hares[-1]

recent = hares[-7:-1]
estimated = np.mean(recent)
error = abs(estimated - true_value) / true_value

print("/n")
print(f"True: {true_value}")
print(f"Estimated: {estimated:.0f}")
print(f"Error ratio: {error:.3f}")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15WG5kwiq72NdaFpTlmWv0BTpM3ywwJGD
# To: /content/populations.txt
# 100%|██████████| 532/532 [00:00<00:00, 1.79MB/s]
# /n
# True: 24700.0
# Estimated: 20233
# Error ratio: 0.181
